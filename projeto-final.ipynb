# %% [markdown]
# ### Tema:
# #### Análise da Infraestrutura Carcerária Feminina em Pernambuco, Paraíba, Piauí e São Paulo: Desafios e Perspectivas no Acolhimento das Mulheres Prisioneiras.

# %% [markdown]
# #### Perguntas
# - 1 - Qual a qCapacidade do estabelecimento nos estados de pe, pb, pi e sp e o tipo e Gestão do estabelecimento?
# - 2 - Possui berçário e/ou centro de referência materno-infantil? Sim. Capacidade de bebês: Quantidade?
# - 3 - Possui creche?  Sim. Capacidade de crianças: Quantidade?
# - 4 - Há equipe própria para atendimento no berçário e/ou creche?  há médico pediatra?
# - 5 - Há equipe própria para atendimento no berçário e/ou creche? há cuidadores/as?
# - 6 - Há equipe própria para atendimento no berçário e/ou creche? os atendimentos são realizados externamente?
# - 7 - Possui Módulo de educação ?
# - 8 - Há local específico para visita íntima?
# - 9 - Há sala de atendimento para psicologia?
# - 10 - Há ala ou cela destinadas exclusivamente às pessoas privadas de liberdade que se declarem lésbicas, gays, bissexuais, travestis e transexuais (LGBT)/quantidade?
# - 11 - Qual a quantidade de estabelcimentos que Há cela adequada/ dormitório para gestantes?
# - 12 - Qual a quantiadde da População prisional | Presos provisórios (sem condenação) | Justiça Estadual e Justiça Federal ?
# - 13 - Qual a quantidade População prisional | Presos sentenciados - regime fechado Justiça Estadual e Federal Feminino?
# - 14 - Qual a quantidade População prisional | Presos sentenciados - regime semiaberto Justiça Estadual e Federal Feminino?
# - 15 - Qual a quantidade População prisional | Presos sentenciados - regime aberto  Justiça Estadual e  Federal Feminino?
# - 16 - Qual a Quantidade de pessoas privadas de liberdade por faixa etária eminino?
# - 17 - Qual a Quantidade de pessoas privadas de liberdade por cor de pele/raça/etnia: Branca, Preta, Parda, Amarela, Indígena Feminino
# - 18 - Qual a Quantidade de pessoas privadas de liberdade por procedência | Área Urbana - Municípios do Interior, Zona Rural e Municípios em Regiões Metropolitanas | Feminino?
# - 19 - Qual a Quantidade Pessoas com deficiência Feminino?  Pessoas com deficiência intelectual, Pessoas com deficiência, Pessoas com deficiência auditiva,deficiência visual, deficiências múltiplas?
# - 20 - Quantas pessoas, dentre as informadas acima, são cadeirantes?
# - 21 - Qual a Quantidade de pessoas privadas de liberdade por grau de instrução | Ensino Fundamental Incompleto, Ensino Fundamental Completo, Ensino Médio Incompleto, Ensino Médio Completo, Ensino Superior Incompleto, Ensino Superior completo, Não Informado   | Feminino?
# - 22 - Qual a Quantidade de pessoas privadas de liberdade por nacionalidade Brasileiro nato e Estrangeiros | Feminino?
# - 23 - Qual a Quantidade de pessoas privadas de liberdade por tempo total de penas (presos/as condenados/as e ) | Mais de 2 até 4 anos (inclusive)/Mais de 4 até 8 anos(inclusive)/Mais de 8 até 15 anos (inclusive)/Mais de 15 até 20 anos(inclusive)/Mais de 20 até 30 anos (inclusive)/Mais de 30 até 50 anos (inclusive)/ Mais de 50 até 100 anos (inclusive)/Mais de 100 anos?
# - 24 - Quais tipos de crimes colunas 5.14 (Homicídio simples/ Crimes contra a pessoa/Crimes contra a dignidade sexual/Tráfico de drogas/ Associação para o tráfico/Tráfico internacional de drogas )
# - 25 - Qual a Quantidade de pessoas privadas de liberdade em programas de laborterapia?
# - 26 - Qual a Quantidade de pessoas privadas de liberdade por remuneração: Não recebe/ Menos do que 3/4 do salário mínimo mensal/Entre 3/4 e 1 salário mínimo mensal/ Entre 1 e 2 salários mínimos mensais/Mais que 2 salários mínimos mensais?
# - 27 - Qual a Quantidade de pessoas trabalhando e estudando, simultaneamente | Pessoas que trabalham e estudam ?
# - 28 - Qual a Quantidade de famílias que recebem auxílio-reclusão | Número de pessoas privadas de liberdade cujas famílias recebem auxílio-reclusão?
# - 29 - Qual a Quantidade de visitas registradas no período de referência | Quantidade de presos que receberam visita no período de referência(2023.1º semestre) | Feminino

# %% [markdown]
# - Número de pessoas privadas de liberdade que possuem visitantes cadastrados | Pessoas com visitantes cadastrados
# - Informações da área de saúde - total do período | Consultas psicológicas
# - Quantidade de pessoas com agravos transmissíveis na data de fim do período de referência | HIV | Feminino 6.6

# %% [markdown]
# Ainda irei releacionar as perguntas para assim realizar minhas analises

# %%
# importando os pacotes que iremos utilizar
import pandas as pd

# %%
df_sistema_prisional_feminino_brasil= pd.read_csv('14o-ciclo-base-de-dados-2023-1-semestre.2.-PB-PE-PI-SP.csv')
df_sistema_prisional_feminino_brasil
# Out:
#    Situação de Preenchimento  \
# 0                   Validado
# 1                   Validado
# 2                   Validado
# 3                   Validado
# 4                   Validado
# 5                   Validado
# 6                   Validado
# 7                   Validado
# 8                   Validado
# 9                   Validado
# 10                  Validado
# 11                  Validado
# 12                  Validado
# 13                  Validado
# 14                  Validado
# 15                  Validado
# 16                  Validado
# 17                  Validado
# 18                  Validado
# 19                  Validado
# 20                  Validado
# 21                  Validado
# 22                  Validado
# 23                  Validado
# 24                  Validado
# 25                  Validado
# 26                  Validado
# 27                  Validado
# 28                  Validado
# 29                  Validado
# 30                  Validado
# ...

# %%
df_sistema_prisional_feminino_brasil.columns
# Out:
# Index(['Situação de Preenchimento', 'Nome do Estabelecimento', 'Âmbito', 'UF',
#        'Município',
#        '1.1 Estabelecimento originalmente destinado a pessoa privadas de liberdade do sexo',
#        '1.2 Tipo de estabelecimento - originalmente destinado',
#        '1.3 Capacidade do estabelecimento | Presos provisórios | Feminino',
#        '1.3 Capacidade do estabelecimento | Regime fechado | Feminino',
#        '1.3 Capacidade do estabelecimento | Regime semiaberto | Feminino',
#        ...
#        '6.2 Quantidade de pessoas privadas de liberdade por remuneração | Não recebe | Feminino',
#        '6.2 Quantidade de pessoas privadas de liberdade por remuneração | Menos do que 3/4 do salário mínimo mensal | Feminino',
#        '6.2 Quantidade de pessoas privadas de liberdade por remuneração | Entre 3/4 e 1 salário mínimo mensal | Feminino',
#        '6.2 Quantidade de pessoas privadas de liberdade por remuneração | Entre 1 e 2 salários mínimos mensais | Feminino',
# ...

# %%
df_sistema_prisional_feminino_brasil.dtypes
# Out:
# Situação de Preenchimento                                                                                                                                object
# Nome do Estabelecimento                                                                                                                                  object
# Âmbito                                                                                                                                                   object
# UF                                                                                                                                                       object
# Município                                                                                                                                                object
#                                                                                                                                                          ...
# ...

# %%
df_sistema_prisional_feminino_brasil.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45 entries, 0 to 44
# Columns: 127 entries, Situação de Preenchimento to 7.3 Quantidade de visitas registradas no período de referência | Quantidade de presos que receberam visita no período de referência | Feminino
# dtypes: float64(105), int64(1), object(21)
# memory usage: 44.8+ KB

# %%
df_Informacoes_prisionais_feminino_doze_paises_mundo = pd.read_csv('Tabela-3-Informações-prisionais-dos-doze-países-com-maior-população-prisional-feminina-do-mundo.csv')
df_Informacoes_prisionais_feminino_doze_paises_mundo
# Out:
#                   País População prisional feminina   \
# 0   Estados Unidos                           211,870
# 1                China                       107,131
# 2               Rússia                        48,478
# 3               Brasil                   42.355 40,6
# 4            Tailândia                   41.119 60,7
# 5                Índia                    17.834 1,4
# 6            Filipinas                   12.658 12,4
# 7               Vietnã                   11.644 12,3
# 8            Indonésia                    11.465 4,4
# 9               México                    10.832 8,8
# 10             Mianmar                    9.807 17,9
# 11             Turquia                         9,708
#
#     Taxa de aprisionamento de mulheres (100 mil/hab)
# 0                                               65.7
# 1                                                7.6
# 2                                               33.5
# 3                                               40.6
# ...

# %%
df_Informacoes_prisionais_feminino_doze_paises_mundo.columns
# Out:
# Index(['País', 'População prisional feminina ',
#        'Taxa de aprisionamento de mulheres (100 mil/hab)'],
#       dtype='object')

# %%
df_Informacoes_prisionais_feminino_doze_paises_mundo.dtypes
# Out:
# País                                                 object
# População prisional feminina                         object
# Taxa de aprisionamento de mulheres (100 mil/hab)    float64
# dtype: object

# %%
df_Informacoes_prisionais_feminino_doze_paises_mundo.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12 entries, 0 to 11
# Data columns (total 3 columns):
#  #   Column                                            Non-Null Count  Dtype
# ---  ------                                            --------------  -----
#  0   País                                              12 non-null     object
#  1   População prisional feminina                      12 non-null     object
#  2   Taxa de aprisionamento de mulheres (100 mil/hab)  12 non-null     float64
# dtypes: float64(1), object(2)
# memory usage: 420.0+ bytes

# %%
#verificando valores nulos
df_sistema_prisional_feminino_brasil.isnull().sum()
# Out:
# Situação de Preenchimento                                                                                                                                0
# Nome do Estabelecimento                                                                                                                                  0
# Âmbito                                                                                                                                                   0
# UF                                                                                                                                                       0
# Município                                                                                                                                                1
#                                                                                                                                                         ..
# ...

# %%
#verificando valores nulos

df_Informacoes_prisionais_feminino_doze_paises_mundo.isnull().sum()
# Out:
# País                                                0
# População prisional feminina                        0
# Taxa de aprisionamento de mulheres (100 mil/hab)    0
# dtype: int64

# %%
#verificando valores a quantidade de nulos

df_sistema_prisional_feminino_brasil.isnull().sum().sum()
# Out:
# 1784

# %%
df_sistema_prisional_feminino_brasil.isnull().sum()
# Out:
# Situação de Preenchimento                                                                                                                                0
# Nome do Estabelecimento                                                                                                                                  0
# Âmbito                                                                                                                                                   0
# UF                                                                                                                                                       0
# Município                                                                                                                                                1
#                                                                                                                                                         ..
# ...

# %%
# data frame sem os nulos
df_sistema_prisional_feminino_brasil
# Out:
#    Situação de Preenchimento  \
# 0                   Validado
# 1                   Validado
# 2                   Validado
# 3                   Validado
# 4                   Validado
# 5                   Validado
# 6                   Validado
# 7                   Validado
# 8                   Validado
# 9                   Validado
# 10                  Validado
# 11                  Validado
# 12                  Validado
# 13                  Validado
# 14                  Validado
# 15                  Validado
# 16                  Validado
# 17                  Validado
# 18                  Validado
# 19                  Validado
# 20                  Validado
# 21                  Validado
# 22                  Validado
# 23                  Validado
# 24                  Validado
# 25                  Validado
# 26                  Validado
# 27                  Validado
# 28                  Validado
# 29                  Validado
# 30                  Validado
# ...

# %%
# Substitir todos os valores nulos por um valor específico, por exemplo, 0
df_sistema_prisional_feminino_brasil = df_sistema_prisional_feminino_brasil.fillna(0)

print(df_sistema_prisional_feminino_brasil)
# Out:
#    Situação de Preenchimento  \
# 0                   Validado
# 1                   Validado
# 2                   Validado
# 3                   Validado
# 4                   Validado
# 5                   Validado
# 6                   Validado
# 7                   Validado
# 8                   Validado
# 9                   Validado
# 10                  Validado
# 11                  Validado
# 12                  Validado
# 13                  Validado
# 14                  Validado
# 15                  Validado
# 16                  Validado
# 17                  Validado
# 18                  Validado
# 19                  Validado
# 20                  Validado
# 21                  Validado
# 22                  Validado
# 23                  Validado
# 24                  Validado
# 25                  Validado
# 26                  Validado
# 27                  Validado
# 28                  Validado
# 29                  Validado
# 30                  Validado
# ...

# %%
# nulos substituidos por zero
df_sistema_prisional_feminino_brasil
# Out:
#    Situação de Preenchimento  \
# 0                   Validado
# 1                   Validado
# 2                   Validado
# 3                   Validado
# 4                   Validado
# 5                   Validado
# 6                   Validado
# 7                   Validado
# 8                   Validado
# 9                   Validado
# 10                  Validado
# 11                  Validado
# 12                  Validado
# 13                  Validado
# 14                  Validado
# 15                  Validado
# 16                  Validado
# 17                  Validado
# 18                  Validado
# 19                  Validado
# 20                  Validado
# 21                  Validado
# 22                  Validado
# 23                  Validado
# 24                  Validado
# 25                  Validado
# 26                  Validado
# 27                  Validado
# 28                  Validado
# 29                  Validado
# 30                  Validado
# ...

# %%
df_sistema_prisional_feminino_brasil.isnull().sum()
# Out:
# Situação de Preenchimento                                                                                                                               0
# Nome do Estabelecimento                                                                                                                                 0
# Âmbito                                                                                                                                                  0
# UF                                                                                                                                                      0
# Município                                                                                                                                               0
#                                                                                                                                                        ..
# ...

# %%
# Use value_counts para contar os diferentes tipos de estabelecimentos com base em duas colunas
contagem_tipos_estabelecimento = df_sistema_prisional_feminino_brasil[['UF', '1.1 Estabelecimento originalmente destinado a pessoa privadas de liberdade do sexo','1.4 Gestão do estabelecimento','2.1 Há cela adequada/ dormitório para gestantes? (apenas para estabelecimentos com vagas para mulheres)']].value_counts()

# Exiba a contagem resultante
contagem_tipos_estabelecimento
# Out:
# UF  1.1 Estabelecimento originalmente destinado a pessoa privadas de liberdade do sexo  1.4 Gestão do estabelecimento  2.1 Há cela adequada/ dormitório para gestantes? (apenas para estabelecimentos com vagas para mulheres)
# SP  Feminino                                                                            Pública                        Sim                                                                                                        10
#                                                                                                                        Não                                                                                                         8
# PB  Misto                                                                               Pública                        Não                                                                                                         4
# ...

# %%
# Supondo que você tenha um DataFrame chamado df_sistema_prisional_feminino_brasil

# Filtrar apenas estabelecimentos femininos (aqueles com vagas para mulheres)
estabelecimentos_femininos = df_sistema_prisional_feminino_brasil[df_sistema_prisional_feminino_brasil['1.1 Estabelecimento originalmente destinado a pessoa privadas de liberdade do sexo'] == 'Feminino']

# Verificar se há cela adequada/dormitório para gestantes
gestantes_presentes = estabelecimentos_femininos[['2.1 Há cela adequada/ dormitório para gestantes? (apenas para estabelecimentos com vagas para mulheres)', '2.2 Possui berçário e/ou centro de referência materno-infantil? (apenas para estabelecimentos com vagas para mulheres)']].value_counts()

# Exiba a contagem resultante
gestantes_presentes
# Out:
# 2.1 Há cela adequada/ dormitório para gestantes? (apenas para estabelecimentos com vagas para mulheres)  2.2 Possui berçário e/ou centro de referência materno-infantil? (apenas para estabelecimentos com vagas para mulheres)
# Sim                                                                                                      Sim. Capacidade de bebês:                                                                                                 11
# Não                                                                                                      Não                                                                                                                       10
# Sim                                                                                                      Não                                                                                                                        5
# ...

# %%
df_sistema_prisional_feminino_brasil
# Out:
#    Situação de Preenchimento  \
# 0                   Validado
# 1                   Validado
# 2                   Validado
# 3                   Validado
# 4                   Validado
# 5                   Validado
# 6                   Validado
# 7                   Validado
# 8                   Validado
# 9                   Validado
# 10                  Validado
# 11                  Validado
# 12                  Validado
# 13                  Validado
# 14                  Validado
# 15                  Validado
# 16                  Validado
# 17                  Validado
# 18                  Validado
# 19                  Validado
# 20                  Validado
# 21                  Validado
# 22                  Validado
# 23                  Validado
# 24                  Validado
# 25                  Validado
# 26                  Validado
# 27                  Validado
# 28                  Validado
# 29                  Validado
# 30                  Validado
# ...

# %%
# Supondo que você tenha um DataFrame chamado df_sistema_prisional_feminino_brasil

# Use value_counts para contar os diferentes tipos de estabelecimentos com base em duas colunas
contagem_tipos_estabelecimento = df_sistema_prisional_feminino_brasil[['UF', '1.1 Estabelecimento originalmente destinado a pessoa privadas de liberdade do sexo','1.4 Gestão do estabelecimento','2.1 Há cela adequada/ dormitório para gestantes? (apenas para estabelecimentos com vagas para mulheres)']].value_counts()

# Exiba a contagem resultante
print(contagem_tipos_estabelecimento)
# Out:
# UF  1.1 Estabelecimento originalmente destinado a pessoa privadas de liberdade do sexo  1.4 Gestão do estabelecimento  2.1 Há cela adequada/ dormitório para gestantes? (apenas para estabelecimentos com vagas para mulheres)
# SP  Feminino                                                                            Pública                        Sim                                                                                                        10
#                                                                                                                        Não                                                                                                         8
# PB  Misto                                                                               Pública                        Não                                                                                                         4
# ...

# %%
# Supondo que você tenha um DataFrame chamado df_sistema_prisional_feminino_brasil

# Filtrar apenas estabelecimentos femininos (aqueles com vagas para mulheres)
estabelecimentos_femininos = df_sistema_prisional_feminino_brasil[df_sistema_prisional_feminino_brasil['1.1 Estabelecimento originalmente destinado a pessoa privadas de liberdade do sexo'] == 'Feminino']

# Verificar se há cela adequada/dormitório para gestantes
gestantes_presentes = estabelecimentos_femininos[['2.1 Há cela adequada/ dormitório para gestantes? (apenas para estabelecimentos com vagas para mulheres)', '2.2 Possui berçário e/ou centro de referência materno-infantil? (apenas para estabelecimentos com vagas para mulheres)']].value_counts()

# Exiba a contagem resultante
print(gestantes_presentes)
# Out:
# 2.1 Há cela adequada/ dormitório para gestantes? (apenas para estabelecimentos com vagas para mulheres)  2.2 Possui berçário e/ou centro de referência materno-infantil? (apenas para estabelecimentos com vagas para mulheres)
# Sim                                                                                                      Sim. Capacidade de bebês:                                                                                                 11
# Não                                                                                                      Não                                                                                                                       10
# Sim                                                                                                      Não                                                                                                                        5
# ...

# %%
# Supondo que 'Feminino' seja uma coluna no DataFrame df_sistema_prisional_feminino_brasil
# e que você queira contar os estabelecimentos femininos
estabelecimentos_femininos = df_sistema_prisional_feminino_brasil[df_sistema_prisional_feminino_brasil['1.1 Estabelecimento originalmente destinado a pessoa privadas de liberdade do sexo'] == 'Feminino']

# Agora, você pode obter a contagem de estabelecimentos femininos
contagem_estabelecimentos_femininos = len(estabelecimentos_femininos)

# Exibir a contagem
print(f"A quantidade de estabelecimentos femininos é: {contagem_estabelecimentos_femininos}")
# Out:
# A quantidade de estabelecimentos femininos é: 31

# %%
# Supondo que 'Feminino' seja uma coluna no DataFrame df_sistema_prisional_feminino_brasil
# e que você queira contar os estabelecimentos femininos
estabelecimentos_Misto = df_sistema_prisional_feminino_brasil[df_sistema_prisional_feminino_brasil['1.1 Estabelecimento originalmente destinado a pessoa privadas de liberdade do sexo'] == 'Misto']

# Agora, você pode obter a contagem de estabelecimentos femininos
contagem_estabelecimentos_Mistos = len(estabelecimentos_Misto)

# Exibir a contagem
print(f"A quantidade de estabelecimentos Misto é: {contagem_estabelecimentos_Mistos}")
# Out:
# A quantidade de estabelecimentos Misto é: 13

# %%
# Supondo que 'df_sistema_prisional_feminino_brasil' seja o DataFrame que contém suas informações
# e que as colunas 'Âmbito', 'UF' e '1.1 Estabelecimento originalmente destinado a pessoa privadas de liberdade do sexo' existam no DataFrame.

# Criar um DataFrame para armazenar as contagens
contagem_estabelecimentos = df_sistema_prisional_feminino_brasil.groupby(['Âmbito', 'UF', '1.1 Estabelecimento originalmente destinado a pessoa privadas de liberdade do sexo']).size().reset_index(name='Contagem')

# Filtrar estabelecimentos Femininos
estabelecimentos_femininos = contagem_estabelecimentos[contagem_estabelecimentos['1.1 Estabelecimento originalmente destinado a pessoa privadas de liberdade do sexo'] == 'Feminino']

# Exibir as contagens por estabelecimentos Femininos
print("Contagem de estabelecimentos Femininos:")
print(estabelecimentos_femininos)
# Out:
# Contagem de estabelecimentos Femininos:
#      Âmbito  UF  \
# 0  Estadual  PB
# 2  Estadual  PE
# 4  Estadual  PI
# 6  Estadual  SP
#
#   1.1 Estabelecimento originalmente destinado a pessoa privadas de liberdade do sexo  \
# 0                                           Feminino
# 2                                           Feminino
# 4                                           Feminino
# 6                                           Feminino
#
#    Contagem
# 0         3
# 2         8
# 4         2
# 6        18

# %%
# Criar um DataFrame para armazenar as contagens
contagem_estabelecimentos = df_sistema_prisional_feminino_brasil.groupby(['Âmbito', 'UF', '1.1 Estabelecimento originalmente destinado a pessoa privadas de liberdade do sexo']).size().reset_index(name='Contagem')
# Filtrar estabelecimentos Misto
estabelecimentos_misto = contagem_estabelecimentos[contagem_estabelecimentos['1.1 Estabelecimento originalmente destinado a pessoa privadas de liberdade do sexo'] == 'Misto']

# Exibir as contagens por estabelecimentos Misto
print("\nContagem de estabelecimentos Misto:")
print(estabelecimentos_misto)
# Out:
# Contagem de estabelecimentos Misto:
#      Âmbito  UF  \
# 1  Estadual  PB
# 3  Estadual  PE
# 5  Estadual  PI
# 8  Estadual  SP
#
#   1.1 Estabelecimento originalmente destinado a pessoa privadas de liberdade do sexo  \
# 1                                              Misto
# 3                                              Misto
# 5                                              Misto
# 8                                              Misto
#
#    Contagem
# 1         4
# 3         4
# 5         2
# 8         3

# %%
# Supondo que 'df_sistema_prisional_feminino_brasil' seja o DataFrame que contém suas informações
# e que as colunas 'Nome do Estabelecimento', 'Âmbito', 'UF' e '1.1 Estabelecimento originalmente destinado a pessoa privadas de liberdade do sexo' existam no DataFrame.

# Criar um DataFrame para armazenar as contagens
contagem_estabelecimentos = df_sistema_prisional_feminino_brasil.groupby(['Nome do Estabelecimento', 'Âmbito', 'UF', '1.1 Estabelecimento originalmente destinado a pessoa privadas de liberdade do sexo']).size().reset_index(name='Contagem')

# Filtrar estabelecimentos Femininos
estabelecimentos_femininos = contagem_estabelecimentos[contagem_estabelecimentos['1.1 Estabelecimento originalmente destinado a pessoa privadas de liberdade do sexo'] == 'Feminino']

# Exibir as contagens por estabelecimentos Femininos
print("Contagem de estabelecimentos Femininos:")
print(estabelecimentos_femininos)
# Out:
# Contagem de estabelecimentos Femininos:
#                               Nome do Estabelecimento    Âmbito  UF  \
# 1   CADEIA PÚBLICA FEMININA DE PETROLINA E SEDE GR...  Estadual  PE
# 2               CADEIA PÚBLICA FEMININA DE VERDEJANTE  Estadual  PE
# 3   CADEIA PÚBLICA FEMININA DE VERDEJANTE - P/ DOM...  Estadual  PE
# 4                     CDP Feminino de Franco da Rocha  Estadual  SP
# 7       COLÔNIA PENAL FEMININA DE ABREU E LIMA - PFAL  Estadual  PE
# 8   COLÔNIA PENAL FEMININA DE ABREU E LIMA - PFAL ...  Estadual  PE
# 9                 CPP Feminino de São Miguel Paulista  Estadual  SP
# 10  CR Feminino "Carlos Sidnes de Souza Cantarelli...  Estadual  SP
# 11        CR Feminino de São José do Rio Preto + ARSA  Estadual  SP
# 13  Centro de  Ressocialização  Feminino de  Rio C...  Estadual  SP
# 16             Centro de Reed. Fem. Mª Júlia Maranhão  Estadual  PB
# 17  Centro de Ressocialização Feminino de Araraqua...  Estadual  SP
# ...

# %%
# Criar um DataFrame para armazenar as contagens
contagem_estabelecimentos = df_sistema_prisional_feminino_brasil.groupby(['Nome do Estabelecimento', 'Âmbito', 'UF', '1.1 Estabelecimento originalmente destinado a pessoa privadas de liberdade do sexo']).size().reset_index(name='Contagem')
# Filtrar estabelecimentos Misto
estabelecimentos_misto = contagem_estabelecimentos[contagem_estabelecimentos['1.1 Estabelecimento originalmente destinado a pessoa privadas de liberdade do sexo'] == 'Misto']
# Exibir as contagens por estabelecimentos Misto
print("\nContagem de estabelecimentos Misto:")
print(estabelecimentos_misto)
# Out:
# Contagem de estabelecimentos Misto:
#                               Nome do Estabelecimento    Âmbito  UF  \
# 0            CADEIA PÚBLICA DE GOIANA - P/ DOMICILIAR  Estadual  PE
# 5      CENTRAL DE MONITORAMENTO ELETRÔNICO DOMICILIAR  Estadual  PI
# 6   CENTRO DE CONTROLE E OPERAÇÕES PENITENCIÁRIAS ...  Estadual  SP
# 12                       Cadeia Pública de Cajazeiras  Estadual  PB
# 14  Centro de Monitoramento de Tornozeleira Eletrô...  Estadual  PB
# 15  Centro de Readaptação Penitenciária " Dr. José...  Estadual  SP
# 22  Hospital  de Custódia e Tratamento Psiquiátric...  Estadual  SP
# 23  Hospital de Custódia e Tratamento Psiquiátrico...  Estadual  PE
# 24      MONITORAMENTO ELETRONICO P/DOMICILIAR - CEMER  Estadual  PE
# 25       PATRONATO PE - Regime Aberto - P/ Domiciliar  Estadual  PE
# 28           PENITENCIÁRIA MISTA JUIZ FONTES IBIAPINA  Estadual  PI
# 41          Penitenciária Jurista Agnelo Amorim Filho  Estadual  PB
# ...

# %%
# Supondo que 'df_sistema_prisional_feminino_brasil' seja o DataFrame que contém suas informações
# e que as colunas 'Nome do Estabelecimento', 'Âmbito', 'UF', 'Município' e '1.1 Estabelecimento originalmente destinado a pessoa privadas de liberdade do sexo' existam no DataFrame.

# Criar um DataFrame para armazenar as contagens
contagem_estabelecimentos = df_sistema_prisional_feminino_brasil.groupby(['Nome do Estabelecimento', 'Âmbito', 'UF', 'Município', '1.1 Estabelecimento originalmente destinado a pessoa privadas de liberdade do sexo']).size().reset_index(name='Contagem')

# Filtrar estabelecimentos Femininos
estabelecimentos_femininos = contagem_estabelecimentos[contagem_estabelecimentos['1.1 Estabelecimento originalmente destinado a pessoa privadas de liberdade do sexo'] == 'Feminino']

# Exibir as contagens por estabelecimentos Femininos
print("Contagem de estabelecimentos Femininos:")
print(estabelecimentos_femininos)
# Out:
# Contagem de estabelecimentos Femininos:
#                               Nome do Estabelecimento    Âmbito  UF  \
# 1   CADEIA PÚBLICA FEMININA DE PETROLINA E SEDE GR...  Estadual  PE
# 2               CADEIA PÚBLICA FEMININA DE VERDEJANTE  Estadual  PE
# 3   CADEIA PÚBLICA FEMININA DE VERDEJANTE - P/ DOM...  Estadual  PE
# 4                     CDP Feminino de Franco da Rocha  Estadual  SP
# 7       COLÔNIA PENAL FEMININA DE ABREU E LIMA - PFAL  Estadual  PE
# 8   COLÔNIA PENAL FEMININA DE ABREU E LIMA - PFAL ...  Estadual  PE
# 9                 CPP Feminino de São Miguel Paulista  Estadual  SP
# 10  CR Feminino "Carlos Sidnes de Souza Cantarelli...  Estadual  SP
# 11        CR Feminino de São José do Rio Preto + ARSA  Estadual  SP
# 13  Centro de  Ressocialização  Feminino de  Rio C...  Estadual  SP
# 16             Centro de Reed. Fem. Mª Júlia Maranhão  Estadual  PB
# 17  Centro de Ressocialização Feminino de Araraqua...  Estadual  SP
# ...

# %%
# Criar um DataFrame para armazenar as contagens
contagem_estabelecimentos = df_sistema_prisional_feminino_brasil.groupby(['Nome do Estabelecimento', 'Âmbito', 'UF', 'Município', '1.1 Estabelecimento originalmente destinado a pessoa privadas de liberdade do sexo']).size().reset_index(name='Contagem')

# Filtrar estabelecimentos Misto
estabelecimentos_misto = contagem_estabelecimentos[contagem_estabelecimentos['1.1 Estabelecimento originalmente destinado a pessoa privadas de liberdade do sexo'] == 'Misto']
# Exibir as contagens por estabelecimentos Misto
print("\nContagem de estabelecimentos Misto:")
print(estabelecimentos_misto)
# Out:
# Contagem de estabelecimentos Misto:
#                               Nome do Estabelecimento    Âmbito  UF  \
# 0            CADEIA PÚBLICA DE GOIANA - P/ DOMICILIAR  Estadual  PE
# 5      CENTRAL DE MONITORAMENTO ELETRÔNICO DOMICILIAR  Estadual  PI
# 6   CENTRO DE CONTROLE E OPERAÇÕES PENITENCIÁRIAS ...  Estadual  SP
# 12                       Cadeia Pública de Cajazeiras  Estadual  PB
# 14  Centro de Monitoramento de Tornozeleira Eletrô...  Estadual  PB
# 15  Centro de Readaptação Penitenciária " Dr. José...  Estadual  SP
# 22  Hospital  de Custódia e Tratamento Psiquiátric...  Estadual  SP
# 23  Hospital de Custódia e Tratamento Psiquiátrico...  Estadual  PE
# 24      MONITORAMENTO ELETRONICO P/DOMICILIAR - CEMER  Estadual  PE
# 25       PATRONATO PE - Regime Aberto - P/ Domiciliar  Estadual  PE
# 28           PENITENCIÁRIA MISTA JUIZ FONTES IBIAPINA  Estadual  PI
# 41          Penitenciária Jurista Agnelo Amorim Filho  Estadual  PB
# ...
